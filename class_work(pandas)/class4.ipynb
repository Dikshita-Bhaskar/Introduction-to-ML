# %%
import pandas as pd

# %%
t = pd.read_csv("Titanic-Dataset.csv")
df = pd.read_csv("tip.csv")

# %%
df.groupby('day').size()
df.groupby('day')['tip'].mean().round(2)
# Out:
# day
# Fri     2.73
# Sat     2.99
# Sun     3.26
# Thur    2.77
# Name: tip, dtype: float64

# %%
df['tip_pct'] = round(df['tip']/df['total_bill']*100,2)
df.head(1)
df.groupby('day')['tip_pct'].mean().round(2)
# Out:
# day
# Fri     16.99
# Sat     15.31
# Sun     16.69
# Thur    16.13
# Name: tip_pct, dtype: float64

# %%
df.groupby('day').mean(numeric_only=True)['tip']
df.groupby('day').sum()['tip']
# Out:
# day
# Fri      51.96
# Sat     260.40
# Sun     247.39
# Thur    171.83
# Name: tip, dtype: float64

# %%
df.head(1)
# Out:
#    total_bill   tip     sex smoker  day    time  size  tip_pct
# 0       16.99  1.01  Female     No  Sun  Dinner     2     5.94

# %%
df.groupby('size')['tip_pct'].mean()
# Out:
# size
# 1    21.727500
# 2    16.571410
# 3    15.214737
# 4    14.594865
# 5    14.152000
# 6    15.620000
# Name: tip_pct, dtype: float64

# %%
df.groupby('size')['total_bill'].mean()
# Out:
# size
# 1     7.242500
# 2    16.448013
# 3    23.277632
# 4    28.613514
# 5    30.068000
# 6    34.830000
# Name: total_bill, dtype: float64

# %%
t.groupby('Pclass')['Survived'].mean()
# Out:
# Pclass
# 1    0.629630
# 2    0.472826
# 3    0.242363
# Name: Survived, dtype: float64

# %%
t.groupby('Pclass')['Fare'].mean()
# Out:
# Pclass
# 1    84.154687
# 2    20.662183
# 3    13.675550
# Name: Fare, dtype: float64

# %%
t.groupby('Embarked').size()
#t.groupby('Age').size()
# Out:
# Embarked
# C    168
# Q     77
# S    644
# dtype: int64
